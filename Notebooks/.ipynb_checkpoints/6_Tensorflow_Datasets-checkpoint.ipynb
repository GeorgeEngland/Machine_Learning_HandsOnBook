# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
    # !pip install -q -U tfx==0.21.2
    print("You can safely ignore the package incompatibility errors.")
except Exception:
    pass

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "../../oxdata/2019-01-10-14-36-48-radar-oxford-10k-partial/radar/data"
CHAPTER_ID = "CART"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, CHAPTER_ID)
print(IMAGES_PATH)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
# Out:
# ../../oxdata/2019-01-10-14-36-48-radar-oxford-10k-partial/radar/data/CART

# %%
filepath_dataset = tf.data.Dataset.list_files(IMAGES_PATH+"/*",seed=42)

# %%
labels = os.listdir(IMAGES_PATH)
train_dataset = tf.keras.preprocessing.image_dataset_from_directory("../../oxdata/2019-01-10-14-36-48-radar-oxford-10k-partial/radar/data",batch_size=10,shuffle=10,labels=labels,color_mode="grayscale")
# Out:
# Found 51 files belonging to 1 classes.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(labels[i])
    plt.axis("off")

# %%
import json
j = json.loads(open('/mnt/c/Users/george.england/Downloads/radiate/junction_1_7/annotations/annotations.json').read())
im=cv2.imread('/mnt/c/Users/george.england/Downloads/radiate/junction_1_7/Navtech_Cartesian/000300.png')
ims = os.listdir('/mnt/c/Users/george.england/Downloads/radiate/junction_1_7/Navtech_Cartesian')
num=500
for id in j:
    id_num = int(id['id'])
    if j[id_num-1]['bboxes'][num] == []:
        continue
    [x,y,width,height] = list(map(int,j[id_num-1]['bboxes'][num]['position']))
    cv2.rectangle(im,(x,y),(x+width,y+height),(255,0,0),5)

plt.imshow(im)

# %%
def get_bounding_boxes(annotations,image_number):
    for id in j:
    id_num = int(id['id'])
    if j[id_num-1]['bboxes'][num] == []:
        continue
    [x,y,width,height] = list(map(int,j[id_num-1]['bboxes'][num]['position']))
    cv2.rectangle(im,(x,y),(x+width,y+height),(255,0,0),5)
    return None
    #return Xmins, Ymins, widths, heights

get_bounding_boxes(j,300)
# Out:
# 10

# %%
#print(ims)
[x,y,width,height] = list(map(int,j[id_num-1]['bboxes'][num]['position']))

CSV = np.array([('filename','width','height','class','xmin','ymin','xmax','ymax')])
for row_num in range(len(ims)):
    get_bounding_boxes(ims)
    
    filename = ims[row_num]
    height = 1152
    width = 1152
    new_arr = np.array([(filename,width,height,class_,xmin,ymin,xmax,ymax)])
    CSV = np.append(CSV,new_arr,axis=0)
print(CSV)
# Out:
# [['filename' 'width' 'height' ... 'ymin' 'xmax' 'ymax']
#  ['1' '2' '3' ... '6' '7' '8']
#  ['1' '2' '3' ... '6' '7' '8']
#  ...
#  ['1' '2' '3' ... '6' '7' '8']
#  ['1' '2' '3' ... '6' '7' '8']
#  ['1' '2' '3' ... '6' '7' '8']]

# %%
# Out:
# The first array is:
#  [[1 2 3]]
# The second array is:
#  [[10 11 12]]
# After append by axis 1, new array is:
#  [[ 1  2  3 10 11 12]]
# After append by axis 0, new array is:
#  [[ 1  2  3]
#  [10 11 12]]
